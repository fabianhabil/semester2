# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
plt.style.use('seaborn-poster')

# %%
x = np.array([0, 2, 4, 6, 9, 11, 12, 15, 17, 19])
y = np.array([5, 6, 7, 6, 9, 8, 7, 10, 12, 12])

A = np.vstack([x, np.ones(len(x))]).T
y = y[:, np.newaxis]

# cara 1
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T, A)), A.T)), y)
print(alpha)

# cara 2 (lstsq)
alpha = np.linalg.lstsq(A, y, rcond=None)[0]
print(alpha)

# cara 3 pseudo inverse
pinv = np.linalg.pinv(A)
alpha = pinv.dot(y)
print(alpha)


# cara 4 scipy
def func(x, a, b):
    y = a*x + b
    return y


alpha = optimize.curve_fit(func, xdata=x, ydata=y)[0]
print(alpha)


xNew =  np.linspace(1, 10, 100)

plt.plot(x, y, "b.")
plt.plot(x, alpha[0]*x + alpha[1], "r")
plt.show()
# Out:
# [[0.35246996]
#  [4.85153538]]
# [[0.35246996]
#  [4.85153538]]
# [[0.35246996]
#  [4.85153538]]
# [ 1.          1.19191919  1.38383838  1.57575758  1.76767677  1.95959596
#   2.15151515  2.34343434  2.53535354  2.72727273  2.91919192  3.11111111
#   3.3030303   3.49494949  3.68686869  3.87878788  4.07070707  4.26262626
#   4.45454545  4.64646465  4.83838384  5.03030303  5.22222222  5.41414141
#   5.60606061  5.7979798   5.98989899  6.18181818  6.37373737  6.56565657
#   6.75757576  6.94949495  7.14141414  7.33333333  7.52525253  7.71717172
#   7.90909091  8.1010101   8.29292929  8.48484848  8.67676768  8.86868687
#   9.06060606  9.25252525  9.44444444  9.63636364  9.82828283 10.02020202
#  10.21212121 10.4040404  10.5959596  10.78787879 10.97979798 11.17171717
#  11.36363636 11.55555556 11.74747475 11.93939394 12.13131313 12.32323232
#  12.51515152 12.70707071 12.8989899  13.09090909 13.28282828 13.47474747
#  13.66666667 13.85858586 14.05050505 14.24242424 14.43434343 14.62626263
#  14.81818182 15.01010101 15.2020202  15.39393939 15.58585859 15.77777778
#  15.96969697 16.16161616 16.35353535 16.54545455 16.73737374 16.92929293
#  17.12121212 17.31313131 17.50505051 17.6969697  17.88888889 18.08080808
#  18.27272727 18.46464646 18.65656566 18.84848485 19.04040404 19.23232323
#  19.42424242 19.61616162 19.80808081 20.        ]
# [ 5.20400534  5.27165109  5.33929684  5.40694259  5.47458834  5.54223409
#   5.60987984  5.67752559  5.74517134  5.81281709  5.88046284  5.94810859
#   6.01575434  6.08340009  6.15104584  6.21869159  6.28633734  6.35398309
#   6.42162884  6.48927459  6.55692034  6.62456609  6.69221184  6.75985759
#   6.82750334  6.89514909  6.96279484  7.03044059  7.09808634  7.16573209
#   7.23337784  7.30102359  7.36866934  7.43631509  7.50396084  7.57160659
#   7.63925234  7.70689809  7.77454384  7.84218959  7.90983534  7.97748109
#   8.04512684  8.11277259  8.18041834  8.24806409  8.31570984  8.38335559
#   8.45100134  8.51864709  8.58629283  8.65393858  8.72158433  8.78923008
#   8.85687583  8.92452158  8.99216733  9.05981308  9.12745883  9.19510458
#   9.26275033  9.33039608  9.39804183  9.46568758  9.53333333  9.60097908
#   9.66862483  9.73627058  9.80391633  9.87156208  9.93920783 10.00685358
#  10.07449933 10.14214508 10.20979083 10.27743658 10.34508233 10.41272808
#  10.48037383 10.54801958 10.61566533 10.68331108 10.75095683 10.81860258
#  10.88624833 10.95389408 11.02153983 11.08918558 11.15683133 11.22447708
#  11.29212283 11.35976858 11.42741433 11.49506008 11.56270583 11.63035158
#  11.69799733 11.76564308 11.83328883 11.90093458]
