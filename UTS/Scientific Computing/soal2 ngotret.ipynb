# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

# Deklarasi data x dan y.
x = np.array([0, 2, 4, 6, 9, 11, 12, 15, 17, 19])
y = np.array([5, 6, 7, 6, 9, 8, 7, 10, 12, 12])

A = np.vstack([x, np.ones(len(x))]).T
y = y[:, np.newaxis]

# Direct Least Squares Regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T, A)), A.T)), y)

# Anggap f(x) = ax + b
# Index pertama dari Direct Least Squares Regression adalah a
a = alpha[0]
# Index kedua dari Direct Least Squares Regression adalah b
b = alpha[1]
print(f"Didapatkan y = {a}x + {b}")
# Out:
# Didapatkan y = [0.35246996]x + [4.85153538]

# %%
# yNew = a*x + b
yNew = (a * x) + b
# Rubah size plot
print(y)
print(yNew)
plt.figure(figsize=(12, 8))
# Plot data awal
plt.plot(x, y, "b.")
# Plot data baru
plt.plot(x, yNew, "r")
plt.legend(["Data Awal", "Data dari Hasil Regresi Fungsi Linear"])
plt.title(f"y = {a}x + {b}")
plt.show()
# Out:
# [[ 5]
#  [ 6]
#  [ 7]
#  [ 6]
#  [ 9]
#  [ 8]
#  [ 7]
#  [10]
#  [12]
#  [12]]
# [ 4.85153538  5.5564753   6.26141522  6.96635514  8.02376502  8.72870494
#   9.0811749  10.13858478 10.8435247  11.54846462]
