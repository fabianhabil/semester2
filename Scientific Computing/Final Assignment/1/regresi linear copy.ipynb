# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

# %%
# Deklarasi data x dan y.
x = np.array([1981, 1983, 1985, 1987, 1989, 1991, 1993, 1995, 1997, 1999])
y = np.array([
    14.1999, 14.2411, 14.0342, 14.2696, 14.197, 14.3055, 14.1853, 14.3577,
    14.4187, 14.3438
])
# Data yang akan diinterpolasi.

A = np.vstack([x, np.ones(len(x))]).T
y = y[:, np.newaxis]

# Direct Least Squares Regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T, A)), A.T)), y)

# Anggap f(x) = ax + b
# Index pertama dari Direct Least Squares Regression adalah a
a = alpha[0][0]
# Index kedua dari Direct Least Squares Regression adalah b
b = alpha[1][0]

X = np.array([1982, 1984, 1986, 1988, 1990, 1992, 1994, 1996, 1998])
Y = a * x + b
Y_rounded = []

print("Hasil Direct Least Squares Regression")
print(f"Didapatkan y = {a}x + {b}")
for i in range(len(x)):
    print(f"{x[i]} = {round(Y[i],4)} asli {y[i]} error {abs(round(Y[i],4) - y[i])}")
    Y_rounded.append(round(Y[i], 4))

# Gambar Grafik
plt.figure(figsize=(12, 8))
plt.title("Hasil Direct Least Squares Regression")
plt.plot(x, y, "b")
plt.plot(x, y, "ro")
plt.plot(x, Y_rounded, "go")
plt.legend(["Garis Data Sample", "Titik Data Sample", "Direct LSQ Regression"])
plt.show()
# Out:
# Hasil Direct Least Squares Regression
# Didapatkan y = 0.012155757575521134x + -9.934677575436439
# 1981 = 14.1459 asli [14.1999] error [0.054]
# 1983 = 14.1702 asli [14.2411] error [0.0709]
# 1985 = 14.1945 asli [14.0342] error [0.1603]
# 1987 = 14.2188 asli [14.2696] error [0.0508]
# 1989 = 14.2431 asli [14.197] error [0.0461]
# 1991 = 14.2674 asli [14.3055] error [0.0381]
# 1993 = 14.2917 asli [14.1853] error [0.1064]
# 1995 = 14.3161 asli [14.3577] error [0.0416]
# 1997 = 14.3404 asli [14.4187] error [0.0783]
# 1999 = 14.3647 asli [14.3438] error [0.0209]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
